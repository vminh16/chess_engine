# %%
import numpy as np

# Tải file .npz
data = np.load('C:\\Users\\USER\\OneDrive\\Máy tính\\chess_engine\\data\\dataset\\dataset_full_2.npz')

# Xem danh sách các mảng có trong file
print(data.files)
# Out:
# ['X', 'y', 'fens']

# %%
print(data['X'][0].shape)
# Out:
# (18, 8, 8)
